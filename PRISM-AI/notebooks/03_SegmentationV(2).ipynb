# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Step 1: Original dataset load

# %%
df = pd.read_csv("/Users/aashishmewada/Desktop/PRISM AI/PRISM-AI/data/raw/customer .csv")

# %%
df.shape
# Out:
# (50000, 28)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'Location', 'Membership',
#        'RegistrationDate', 'Tenure', 'TotalSpend', 'TotalTransactions',
#        'AverageOrderValue', 'PurchaseFrequency', 'LastPurchaseDays',
#        'PreferredCategory', 'WebsiteVisits', 'AppUsageMinutes',
#        'LoginFrequency', 'WishlistCount', 'CartAbandonmentRate',
#        'EmailOpenRate', 'MarketingClicks', 'SatisfactionScore', 'Rating',
#        'SupportCalls', 'Complaints', 'Reviews', 'CustomerHealthScore',
#        'ChurnRisk'],
#       dtype='str')

# %%
remove_cols =[ 
            "CustomerID",
            "RegistrationDate",
            "ChurnRisk"
             ]

# %%
df_model = df.drop(
    columns=remove_cols,
    errors='ignore'
)

# %%
df_model.head()
# Out:
#    Age  Gender    Income Location Membership  Tenure  TotalSpend  \
# 0   54  Female  72543.43       NJ       Gold    6.81     4389.80
# 1   42    Male  78149.18       AZ     Silver    5.14      706.89
# 2   24  Female  48635.85       MD       Free    0.37     2935.65
# 3   31    Male  19935.67       GA       Free    1.11     1410.68
# 4   45  Female  83500.57       AZ     Silver    6.80     4352.92
#
#    TotalTransactions  AverageOrderValue  PurchaseFrequency  ...  \
# 0                 30             146.33                  3  ...
# 1                  2             353.45                  2  ...
# 2                 20             146.78                  3  ...
# 3                 32              44.08                  2  ...
# 4                 69              63.09                  5  ...
#
#    WishlistCount CartAbandonmentRate  EmailOpenRate  MarketingClicks  \
# 0           14.0                48.5           65.6               79
# 1            7.0                87.9           23.4                0
# 2           50.0                87.8           62.3               24
# 3           30.0                73.0           32.0               23
# 4           19.0                25.5           59.0               38
#
#    SatisfactionScore  Rating  SupportCalls  Complaints  Reviews  \
# 0                 65     3.2             0           2      8.0
# 1                  1     0.0             5          18      0.0
# 2                 55     2.8             7           1     23.0
# 3                 74     3.7             5           3      3.0
# 4                 77     3.8             4           2     17.0
#
#    CustomerHealthScore
# 0                 31.8
# 1                 11.6
# 2                 18.2
# 3                 21.0
# 4                 36.4
#
# [5 rows x 25 columns]

# %%
df_model.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Income                 2236
# Location                  0
# Membership                0
# Tenure                    0
# TotalSpend                0
# TotalTransactions         0
# AverageOrderValue         0
# PurchaseFrequency         0
# LastPurchaseDays          0
# PreferredCategory         0
# WebsiteVisits             0
# AppUsageMinutes           0
# LoginFrequency            0
# WishlistCount          1110
# CartAbandonmentRate    1253
# EmailOpenRate          2402
# MarketingClicks           0
# SatisfactionScore         0
# Rating                 1824
# SupportCalls              0
# Complaints                0
# Reviews                2375
# CustomerHealthScore       0
# dtype: int64

# %%
num_cols = df_model.select_dtypes(
    include=np.number
).columns

# %%
for col in num_cols:
    df_model[col] = df_model[col].fillna(
        df_model[col].median()
    )

# %%
df_model.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Income                 0
# Location               0
# Membership             0
# Tenure                 0
# TotalSpend             0
# TotalTransactions      0
# AverageOrderValue      0
# PurchaseFrequency      0
# LastPurchaseDays       0
# PreferredCategory      0
# WebsiteVisits          0
# AppUsageMinutes        0
# LoginFrequency         0
# WishlistCount          0
# CartAbandonmentRate    0
# EmailOpenRate          0
# MarketingClicks        0
# SatisfactionScore      0
# Rating                 0
# SupportCalls           0
# Complaints             0
# Reviews                0
# CustomerHealthScore    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cat_cols = df_model.select_dtypes(
    include="object",
    
).columns
# Out:
# /var/folders/rf/55f17gkd0fs1mt6d7fkb_x340000gn/T/ipykernel_27137/1007304183.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df_model.select_dtypes(

# %%
encoder={}

# %%
for col in cat_cols:
    
    le=LabelEncoder()
    
    df_model[col]=le.fit_transform(
        df_model[col]
    )
    
    encoder[col]=le

# %%
features=[

"Age",
"Income",
"Tenure",

"TotalSpend",
"TotalTransactions",
"AverageOrderValue",
"PurchaseFrequency",

"LastPurchaseDays",

"WebsiteVisits",
"AppUsageMinutes",
"LoginFrequency",

"WishlistCount",

"CartAbandonmentRate",

"EmailOpenRate",

"MarketingClicks",

"SatisfactionScore",

"Rating",

"SupportCalls",

"Complaints",

"Reviews",

"CustomerHealthScore"

]

# %%
X=df_model[features]


X.shape
# Out:
# (50000, 21)

# %%
print("NaN in X before scaling:", X.isnull().sum().sum())

from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

print("NaN in X_scaled:", np.isnan(X_scaled).sum())
# Out:
# NaN in X before scaling: 0
# NaN in X_scaled: 0

# %%
np.isnan(X_scaled).sum()
# Out:
# np.int64(0)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


scores={}

# %%
np.isnan(X_scaled).sum()
# Out:
# np.int64(0)

# %%
len(df)
# Out:
# 50000

# %%
from sklearn.cluster import KMeans

# %%
from sklearn.cluster import KMeans

# Model
final_model = KMeans(
    n_clusters=2,
    random_state=42,
    n_init=100
)


# Train
clusters = final_model.fit_predict(X_scaled)


# Add cluster
df.loc[:, "Customer_Segment"] = clusters


print(df["Customer_Segment"].value_counts())
# Out:
# Customer_Segment
# 1    42467
# 0     7533
# Name: count, dtype: int64

# %%
final_model=KMeans(
    n_clusters=2,
    random_state=42,
    n_init=100
)


clusters=final_model.fit_predict(
    X_scaled
)


df["Customer_Segment"]=clusters

# %%
df["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# 1    42467
# 0     7533
# Name: count, dtype: int64

# %%
segment_profile=df.groupby(
"Customer_Segment"
)[features].mean()


segment_profile
# Out:
#                         Age         Income    Tenure    TotalSpend  \
# Customer_Segment
# 0                 48.809239  196536.554432  3.526886  49318.403839
# 1                 41.901547   59097.890534  3.507384   5133.504676
#
#                   TotalTransactions  AverageOrderValue  PurchaseFrequency  \
# Customer_Segment
# 0                        120.456392         494.864545          19.121333
# 1                         30.112464         232.508753           4.647656
#
#                   LastPurchaseDays  WebsiteVisits  AppUsageMinutes  ...  \
# Customer_Segment                                                    ...
# 0                        14.424665     188.957786      3272.378734  ...
# 1                        91.092024      57.944639       741.337980  ...
#
#                   WishlistCount  CartAbandonmentRate  EmailOpenRate  \
# Customer_Segment
# 0                     85.933007            17.465992      74.905955
# 1                     33.212685            56.661038      40.120365
#
#                   MarketingClicks  SatisfactionScore    Rating  SupportCalls  \
# Customer_Segment
# 0                      120.342626          90.099960  4.503988      1.504049
# 1                       38.485365          61.674147  3.083505      6.450208
#
#                   Complaints    Reviews  CustomerHealthScore
# Customer_Segment
# 0                   0.507766  60.504594            73.438484
# 1                   3.743825  16.269578            27.534076
#
# [2 rows x 21 columns]

# %%
segment_names={

0:"Premium Loyal Customers",

1:"Regular Customers",

2:"At Risk Customers"

}


df["Segment_Name"]=df[
"Customer_Segment"
].map(segment_names)

# %%
import joblib


joblib.dump(
    final_model,
    "customer_segmentation.pkl"
)


joblib.dump(
    scaler,
    "segmentation_scaler.pkl"
)
# Out:
# ['segmentation_scaler.pkl']

# %%
new_customer=pd.DataFrame({

"Age":[45],
"Income":[85000],
"Tenure":[5],
"TotalSpend":[12000],
"TotalTransactions":[60],
"AverageOrderValue":[200],
"PurchaseFrequency":[8],
"LastPurchaseDays":[20],
"WebsiteVisits":[50],
"AppUsageMinutes":[300],
"LoginFrequency":[40],
"WishlistCount":[20],
"CartAbandonmentRate":[20],
"EmailOpenRate":[70],
"MarketingClicks":[50],
"SatisfactionScore":[85],
"Rating":[4.5],
"SupportCalls":[1],
"Complaints":[0],
"Reviews":[40],
"CustomerHealthScore":[80]

})


scaled=scaler.transform(
new_customer
)


prediction=final_model.predict(
scaled
)


print(
"Customer Segment:",
prediction[0]
)
# Out:
# Customer Segment: 1

# %%
import pandas as pd

new_customer = pd.DataFrame({

    "Age":[45],
    "Gender":[0],
    "Income":[85000],
    "Location":[5],
    "Membership":[3],
    "Tenure":[5],

    "TotalSpend":[12000],
    "TotalTransactions":[60],
    "AverageOrderValue":[200],
    "PurchaseFrequency":[8],

    "LastPurchaseDays":[20],

    "PreferredCategory":[2],

    "WebsiteVisits":[50],
    "AppUsageMinutes":[300],
    "LoginFrequency":[40],

    "WishlistCount":[20],

    "CartAbandonmentRate":[20],
    "EmailOpenRate":[70],

    "MarketingClicks":[50],

    "SatisfactionScore":[85],
    "Rating":[4.5],

    "SupportCalls":[1],
    "Complaints":[0],

    "Reviews":[40],

    "CustomerHealthScore":[80]

})


new_customer
# Out:
#    Age  Gender  Income  Location  Membership  Tenure  TotalSpend  \
# 0   45       0   85000         5           3       5       12000
#
#    TotalTransactions  AverageOrderValue  PurchaseFrequency  ...  \
# 0                 60                200                  8  ...
#
#    WishlistCount  CartAbandonmentRate  EmailOpenRate  MarketingClicks  \
# 0             20                   20             70               50
#
#    SatisfactionScore  Rating  SupportCalls  Complaints  Reviews  \
# 0                 85     4.5             1           0       40
#
#    CustomerHealthScore
# 0                   80
#
# [1 rows x 25 columns]

# %%
new_customer.columns.equals(X.columns)
# Out:
# False

# %%
print("Training columns:")
print(X.columns.tolist())


print("\nTesting columns:")
print(new_customer.columns.tolist())
# Out:
# Training columns:
# ['Age', 'Income', 'Tenure', 'TotalSpend', 'TotalTransactions', 'AverageOrderValue', 'PurchaseFrequency', 'LastPurchaseDays', 'WebsiteVisits', 'AppUsageMinutes', 'LoginFrequency', 'WishlistCount', 'CartAbandonmentRate', 'EmailOpenRate', 'MarketingClicks', 'SatisfactionScore', 'Rating', 'SupportCalls', 'Complaints', 'Reviews', 'CustomerHealthScore']
#
# Testing columns:
# ['Age', 'Gender', 'Income', 'Location', 'Membership', 'Tenure', 'TotalSpend', 'TotalTransactions', 'AverageOrderValue', 'PurchaseFrequency', 'LastPurchaseDays', 'PreferredCategory', 'WebsiteVisits', 'AppUsageMinutes', 'LoginFrequency', 'WishlistCount', 'CartAbandonmentRate', 'EmailOpenRate', 'MarketingClicks', 'SatisfactionScore', 'Rating', 'SupportCalls', 'Complaints', 'Reviews', 'CustomerHealthScore']

# %%
remove_test_cols = [
    "Gender",
    "Location",
    "Membership",
    "PreferredCategory"
]


new_customer = new_customer.drop(
    columns=remove_test_cols
)

# %%
new_customer = new_customer[X.columns]

# %%
new_customer.columns.equals(X.columns)
# Out:
# True

# %%
new_scaled = scaler.transform(
    new_customer
)


prediction = final_model.predict(
    new_scaled
)


print(
    "Customer Segment:",
    prediction[0]
)
# Out:
# Customer Segment: 1

# %%
segment_analysis = df.groupby(
    "Customer_Segment"
)[X.columns].mean()

segment_analysis
# Out:
#                         Age         Income    Tenure    TotalSpend  \
# Customer_Segment
# 0                 48.809239  196536.554432  3.526886  49318.403839
# 1                 41.901547   59097.890534  3.507384   5133.504676
#
#                   TotalTransactions  AverageOrderValue  PurchaseFrequency  \
# Customer_Segment
# 0                        120.456392         494.864545          19.121333
# 1                         30.112464         232.508753           4.647656
#
#                   LastPurchaseDays  WebsiteVisits  AppUsageMinutes  ...  \
# Customer_Segment                                                    ...
# 0                        14.424665     188.957786      3272.378734  ...
# 1                        91.092024      57.944639       741.337980  ...
#
#                   WishlistCount  CartAbandonmentRate  EmailOpenRate  \
# Customer_Segment
# 0                     85.933007            17.465992      74.905955
# 1                     33.212685            56.661038      40.120365
#
#                   MarketingClicks  SatisfactionScore    Rating  SupportCalls  \
# Customer_Segment
# 0                      120.342626          90.099960  4.503988      1.504049
# 1                       38.485365          61.674147  3.083505      6.450208
#
#                   Complaints    Reviews  CustomerHealthScore
# Customer_Segment
# 0                   0.507766  60.504594            73.438484
# 1                   3.743825  16.269578            27.534076
#
# [2 rows x 21 columns]

# %%
segment_analysis = df.groupby(
    "Customer_Segment"
)[X.columns].mean()

segment_analysis
# Out:
#                         Age         Income    Tenure    TotalSpend  \
# Customer_Segment
# 0                 48.809239  196536.554432  3.526886  49318.403839
# 1                 41.901547   59097.890534  3.507384   5133.504676
#
#                   TotalTransactions  AverageOrderValue  PurchaseFrequency  \
# Customer_Segment
# 0                        120.456392         494.864545          19.121333
# 1                         30.112464         232.508753           4.647656
#
#                   LastPurchaseDays  WebsiteVisits  AppUsageMinutes  ...  \
# Customer_Segment                                                    ...
# 0                        14.424665     188.957786      3272.378734  ...
# 1                        91.092024      57.944639       741.337980  ...
#
#                   WishlistCount  CartAbandonmentRate  EmailOpenRate  \
# Customer_Segment
# 0                     85.933007            17.465992      74.905955
# 1                     33.212685            56.661038      40.120365
#
#                   MarketingClicks  SatisfactionScore    Rating  SupportCalls  \
# Customer_Segment
# 0                      120.342626          90.099960  4.503988      1.504049
# 1                       38.485365          61.674147  3.083505      6.450208
#
#                   Complaints    Reviews  CustomerHealthScore
# Customer_Segment
# 0                   0.507766  60.504594            73.438484
# 1                   3.743825  16.269578            27.534076
#
# [2 rows x 21 columns]

# %%
len(set(clusters))
# Out:
# 2

# %%
X_scaled.mean(axis=0)
# Out:
# array([ 1.91278104e-16, -1.42392764e-16, -3.52287088e-16, -8.29913915e-17,
#        -3.89377419e-17,  4.60431693e-17, -2.89901436e-17,  3.29691829e-17,
#        -7.31859018e-17,  1.19086963e-16,  1.43529633e-17, -3.86535248e-17,
#        -1.00897068e-16,  1.62856395e-16,  2.38742359e-17,  2.26521024e-16,
#         3.74598130e-16, -5.45696821e-17,  2.27373675e-17, -5.94013727e-17,
#        -1.19371180e-16])

# %%
X = df_model[features]

# %%
features = [
    "Age",
    "Income",
    "Tenure",
    "TotalSpend",
    "TotalTransactions",
    "AverageOrderValue",
    "PurchaseFrequency",
    "LastPurchaseDays",
    "WebsiteVisits",
    "AppUsageMinutes",
    "LoginFrequency",
    "WishlistCount",
    "CartAbandonmentRate",
    "EmailOpenRate",
    "MarketingClicks",
    "SatisfactionScore",
    "Rating",
    "SupportCalls",
    "Complaints",
    "Reviews",
    "CustomerHealthScore"
]


X = df[features]

# %%
df["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# 1    42467
# 0     7533
# Name: count, dtype: int64

# %%
X.shape
X_scaled.shape
np.isnan(X_scaled).sum()
# Out:
# np.int64(0)

# %%
segment_analysis = df.groupby(
    "Customer_Segment"
).mean(numeric_only=True)

segment_analysis
# Out:
#                         Age         Income    Tenure    TotalSpend  \
# Customer_Segment
# 0                 48.809239  196536.554432  3.526886  49318.403839
# 1                 41.901547   59097.890534  3.507384   5133.504676
#
#                   TotalTransactions  AverageOrderValue  PurchaseFrequency  \
# Customer_Segment
# 0                        120.456392         494.864545          19.121333
# 1                         30.112464         232.508753           4.647656
#
#                   LastPurchaseDays  WebsiteVisits  AppUsageMinutes  ...  \
# Customer_Segment                                                    ...
# 0                        14.424665     188.957786      3272.378734  ...
# 1                        91.092024      57.944639       741.337980  ...
#
#                   WishlistCount  CartAbandonmentRate  EmailOpenRate  \
# Customer_Segment
# 0                     85.933007            17.465992      74.905955
# 1                     33.212685            56.661038      40.120365
#
#                   MarketingClicks  SatisfactionScore    Rating  SupportCalls  \
# Customer_Segment
# 0                      120.342626          90.099960  4.503988      1.504049
# 1                       38.485365          61.674147  3.083505      6.450208
#
#                   Complaints    Reviews  CustomerHealthScore
# Customer_Segment
# 0                   0.507766  60.504594            73.438484
# 1                   3.743825  16.269578            27.534076
#
# [2 rows x 21 columns]

# %%
df_model["Customer_Segment"] = df["Customer_Segment"]
df_model["Segment_Name"] = df["Segment_Name"]

df_model[
[
"Customer_Segment",
"Segment_Name"
]
].head()
# Out:
#    Customer_Segment       Segment_Name
# 0                 1  Regular Customers
# 1                 1  Regular Customers
# 2                 1  Regular Customers
# 3                 1  Regular Customers
# 4                 1  Regular Customers

# %%
new_customer = pd.DataFrame({

"Age":[45],
"Income":[85000],
"Tenure":[5],
"TotalSpend":[12000],
"TotalTransactions":[60],
"AverageOrderValue":[200],
"PurchaseFrequency":[8],
"LastPurchaseDays":[20],
"WebsiteVisits":[100],
"AppUsageMinutes":[500],
"LoginFrequency":[80],
"WishlistCount":[20],
"CartAbandonmentRate":[10],
"EmailOpenRate":[70],
"MarketingClicks":[50],
"SatisfactionScore":[85],
"Rating":[4.5],
"SupportCalls":[1],
"Complaints":[0],
"Reviews":[40],
"CustomerHealthScore":[80]

})

# %%
new_scaled = scaler.transform(
    new_customer
)

# %%
prediction = final_model.predict(
    new_scaled
)


print(
    "Customer Segment:",
    prediction[0]
)
# Out:
# Customer Segment: 1

# %%
# from sklearn.cluster import KMeans
# from sklearn.metrics import silhouette_score


# for k in range(2,8):

#     model = KMeans(
#         n_clusters=k,
#         random_state=42,
#         n_init=100
#     )

#     labels = model.fit_predict(X_scaled)

#     score = silhouette_score(
#         X_scaled,
#         labels
#     )

#     print(
#         f"K={k}: {score}"
#     )

# %%
from sklearn.metrics import silhouette_score

score = silhouette_score(
    X_scaled,
    clusters
)

print("Silhouette Score:", score)
# Out:
# Silhouette Score: 0.4676790971835295

# %%
segmentation_features = [

"Income",
"TotalSpend",
"TotalTransactions",
"AverageOrderValue",
"PurchaseFrequency",
"LastPurchaseDays",
"WebsiteVisits",
"LoginFrequency",
"CustomerHealthScore",
"SupportCalls",
"Complaints",
"SatisfactionScore"

]

# %%
df_model["Recency"] = 1 / (df["LastPurchaseDays"] + 1)

# %%
df_model["Frequency"] = df["TotalTransactions"]

# %%
df_model["Monetary"] = df["TotalSpend"]

# %%
df_model.columns
# Out:
# Index(['Age', 'Gender', 'Income', 'Location', 'Membership', 'Tenure',
#        'TotalSpend', 'TotalTransactions', 'AverageOrderValue',
#        'PurchaseFrequency', 'LastPurchaseDays', 'PreferredCategory',
#        'WebsiteVisits', 'AppUsageMinutes', 'LoginFrequency', 'WishlistCount',
#        'CartAbandonmentRate', 'EmailOpenRate', 'MarketingClicks',
#        'SatisfactionScore', 'Rating', 'SupportCalls', 'Complaints', 'Reviews',
#        'CustomerHealthScore', 'Customer_Segment', 'Segment_Name', 'Recency',
#        'Frequency', 'Monetary'],
#       dtype='str')

# %%
features = [
    "Income",
    "TotalSpend",
    "TotalTransactions",
    "AverageOrderValue",
    "PurchaseFrequency",
    "LastPurchaseDays",
    "WebsiteVisits",
    "AppUsageMinutes",
    "LoginFrequency",
    "CustomerHealthScore",
    "SatisfactionScore",
    "SupportCalls",
    "Complaints",

]


X = df_model[features]

# %%
import numpy as np


df_model["LogSpend"] = np.log1p(
    df["TotalSpend"]
)


df_model["LogIncome"] = np.log1p(
    df["Income"]
)

# %%
df_model.isnull().sum()
# Out:
# Age                       0
# Gender                    0
# Income                    0
# Location                  0
# Membership                0
# Tenure                    0
# TotalSpend                0
# TotalTransactions         0
# AverageOrderValue         0
# PurchaseFrequency         0
# LastPurchaseDays          0
# PreferredCategory         0
# WebsiteVisits             0
# AppUsageMinutes           0
# LoginFrequency            0
# WishlistCount             0
# CartAbandonmentRate       0
# EmailOpenRate             0
# MarketingClicks           0
# SatisfactionScore         0
# Rating                    0
# SupportCalls              0
# Complaints                0
# Reviews                   0
# CustomerHealthScore       0
# Customer_Segment          0
# Segment_Name              0
# Recency                   0
# Frequency                 0
# Monetary                  0
# LogSpend                  0
# LogIncome              2236
# dtype: int64

# %%
df_model["Income"].isnull().sum()
# Out:
# np.int64(0)

# %%
df_model["Income"] = df["Income"].fillna(
    df["Income"].median()
)

# %%
df_model.drop(
    columns=["LogIncome"],
    inplace=True,
    errors="ignore"
)

# %%
import numpy as np

df_model["LogIncome"] = np.log1p(
    df["Income"]
)

# %%
from sklearn.preprocessing import StandardScaler


X = df_model[features]


scaler = StandardScaler()


X_scaled = scaler.fit_transform(X)

# %%
X.isnull().sum().sort_values(ascending=False)
# Out:
# Income                 0
# TotalSpend             0
# TotalTransactions      0
# AverageOrderValue      0
# PurchaseFrequency      0
# LastPurchaseDays       0
# WebsiteVisits          0
# AppUsageMinutes        0
# LoginFrequency         0
# CustomerHealthScore    0
# SatisfactionScore      0
# SupportCalls           0
# Complaints             0
# dtype: int64

# %%
import numpy as np

np.isnan(X_scaled).sum()
# Out:
# np.int64(0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score


k4 = KMeans(
    n_clusters=4,
    random_state=42,
    n_init=200
)


labels = k4.fit_predict(
    X_scaled
)


score = silhouette_score(
    X_scaled,
    labels
)


print(score)
# Out:
# 0.3423977838756287

# %%
from sklearn.decomposition import PCA


pca = PCA(
    n_components=5
)


X_pca = pca.fit_transform(
    X_scaled
)

# %%
k4.fit_predict(X_pca)
# Out:
# array([1, 2, 3, ..., 3, 1, 2], shape=(50000,), dtype=int32)

# %%
df_model["Customer_Segment"] = labels


df_model["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# 2    19975
# 0    12821
# 1     9760
# 3     7444
# Name: count, dtype: int64

# %%
segment_profile[[
"Income",
"TotalSpend",
"TotalTransactions",
"AverageOrderValue",
"PurchaseFrequency",
"LastPurchaseDays",
"CustomerHealthScore",
"SatisfactionScore",
"SupportCalls",
"Complaints"
]]
# Out:
#                          Income    TotalSpend  TotalTransactions  \
# Customer_Segment
# 0                 196536.554432  49318.403839         120.456392
# 1                  59097.890534   5133.504676          30.112464
#
#                   AverageOrderValue  PurchaseFrequency  LastPurchaseDays  \
# Customer_Segment
# 0                        494.864545          19.121333         14.424665
# 1                        232.508753           4.647656         91.092024
#
#                   CustomerHealthScore  SatisfactionScore  SupportCalls  \
# Customer_Segment
# 0                           73.438484          90.099960      1.504049
# 1                           27.534076          61.674147      6.450208
#
#                   Complaints
# Customer_Segment
# 0                   0.507766
# 1                   3.743825

# %%
segment_profile = df_model.groupby(
    "Customer_Segment"
).mean()

segment_profile
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 segment_profile = df_model.groupby(
#       2     "Customer_Segment"
# ----> 3 ).mean()
#       4
#       5 segment_profile
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:2285, in GroupBy.mean(self, numeric_only, skipna, engine, engine_kwargs)
#    2277     return self._numba_agg_general(
#    2278         grouped_mean,
#    2279         executor.float_dtype_mapping,
#    (...)   2282         skipna=skipna,
#    2283     )
#    2284 else:
# -> 2285     result = self._cython_agg_general(
#    2286         "mean",
#    2287         alt=lambda x: Series(x, copy=False).mean(
#    2288             numeric_only=numeric_only, skipna=skipna
#    2289         ),
#    2290         numeric_only=numeric_only,
#    2291         skipna=skipna,
#    2292     )
#    2293     return result.__finalize__(self.obj, method="groupby")
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1808, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1805     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1806     return result
# -> 1808 new_mgr = data.grouped_reduce(array_func)
#    1809 res = self._wrap_agged_manager(new_mgr)
#    1810 if how in ["idxmin", "idxmax"]:
#    1811     # mypy expects how to be Literal["idxmin", "idxmax"].
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/internals/managers.py:1667, in BlockManager.grouped_reduce(self, func)
#    1665             result_blocks = extend_blocks(applied, result_blocks)
#    1666     else:
# -> 1667         applied = blk.apply(func)
#    1668         result_blocks = extend_blocks(applied, result_blocks)
#    1670 if len(result_blocks) == 0:
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/internals/blocks.py:347, in Block.apply(self, func, **kwargs)
#     341 @final
#     342 def apply(self, func, **kwargs) -> list[Block]:
#     343     """
#     344     apply the function to my values; return a block if we are not
#     345     one
#     346     """
# --> 347     result = func(self.values, **kwargs)
#     349     result = maybe_coerce_values(result)
#     350     return self._split_op_result(result)
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/groupby/groupby.py:1783, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1781 def array_func(values: ArrayLike) -> ArrayLike:
#    1782     try:
# -> 1783         result = self._grouper._cython_operation(
#    1784             "aggregate",
#    1785             values,
#    1786             how,
#    1787             axis=data.ndim - 1,
#    1788             min_count=min_count,
#    1789             **kwargs,
#    1790         )
#    1791     except NotImplementedError:
#    1792         # generally if we have numeric_only=False
#    1793         # and non-applicable functions
#    1794         # try to python agg
#    1795         # TODO: shouldn't min_count matter?
#    1796         # TODO: avoid special casing SparseArray here
#    1797         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:963, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     959 assert kind in ["transform", "aggregate"]
#     961 cy_op = WrappedCythonOp(kind=kind, how=how, has_dropped_na=self.has_dropped_na)
# --> 963 return cy_op.cython_operation(
#     964     values=values,
#     965     axis=axis,
#     966     min_count=min_count,
#     967     comp_ids=self.ids,
#     968     ngroups=self.ngroups,
#     969     **kwargs,
#     970 )
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/groupby/ops.py:553, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     549 self._validate_axis(axis, values)
#     551 if not isinstance(values, np.ndarray):
#     552     # i.e. ExtensionArray
# --> 553     return values._groupby_op(
#     554         how=self.how,
#     555         has_dropped_na=self.has_dropped_na,
#     556         min_count=min_count,
#     557         ngroups=ngroups,
#     558         ids=comp_ids,
#     559         **kwargs,
#     560     )
#     562 return self._cython_op_ndim_compat(
#     563     values,
#     564     min_count=min_count,
#    (...)    568     **kwargs,
#     569 )
#
# File ~/Desktop/PRISM AI/.venv/lib/python3.14/site-packages/pandas/core/arrays/base.py:2808, in ExtensionArray._groupby_op(self, how, has_dropped_na, min_count, ngroups, ids, **kwargs)
#    2794 if isinstance(self.dtype, StringDtype):
#    2795     # StringArray
#    2796     if op.how in [
#    2797         "prod",
#    2798         "mean",
#    (...)   2806         "kurt",
#    2807     ]:
# -> 2808         raise TypeError(
#    2809             f"dtype '{self.dtype}' does not support operation '{how}'"
#    2810         )
#    2811     if op.how not in ["any", "all"]:
#    2812         # Fail early to avoid conversion to object
#    2813         op._get_cython_function(op.kind, op.how, np.dtype(object), False)
#
# TypeError: dtype 'str' does not support operation 'mean'
