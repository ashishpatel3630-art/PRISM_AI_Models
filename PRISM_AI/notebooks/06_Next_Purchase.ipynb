# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor
)

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

import joblib

# %%
df = pd.read_csv("/Users/aashishmewada/Desktop/PRISM AI/PRISM_AI/data/raw/CLV .csv")

df.head()
# Out:
#   CustomerID  Age  Gender  Income      Location Membership RegistrationDate  \
# 0  CUST-1001   58    Male   75927       Seattle      Basic       2024-11-15
# 1  CUST-1002   66    Male   40538   Los Angeles      Basic       2024-04-14
# 2  CUST-1003   41    Male   99742  Philadelphia       Gold       2025-03-29
# 3  CUST-1004   59  Female   52220        Austin      Basic       2023-11-05
# 4  CUST-1005   18  Female   70323   Los Angeles       Gold       2022-08-05
#
#    Tenure  TotalSpend  TotalTransactions  ...  CustomerLifetimeValue  \
# 0    19.5     3171.20                 16  ...                5959.50
# 1    26.5    12463.47                 69  ...               20844.34
# 2    15.1    11819.42                 34  ...               17037.61
# 3    31.8     3657.69                 27  ...                7580.91
# 4    46.8     7877.67                111  ...               17058.40
#
#    NextPurchaseAmount  NextPurchaseDays DiscountUsed  CouponUsed  \
# 0              185.95                41            0           0
# 1              204.44                 6           37           5
# 2              327.34                 7           17           2
# 3              158.07                35           12           9
# 4               84.22                13           47          10
#
#    ReferralCount           PaymentMethod  DeviceType  ReturnRate  \
# 0              1               Apple Pay      Mobile        0.05
# 1              2             Credit Card      Mobile        0.11
# 2              0  BNPL (Klarna/Afterpay)     Desktop        0.08
# 3              5  BNPL (Klarna/Afterpay)      Mobile        0.14
# 4              0  BNPL (Klarna/Afterpay)      Tablet        0.15
#
#    LoyaltyPoints
# 0          31712
# 1         122784
# 2         176441
# 3          35976
# 4         115815
#
# [5 rows x 38 columns]

# %%
df.isnull().sum()
# Out:
# CustomerID               0
# Age                      0
# Gender                   0
# Income                   0
# Location                 0
# Membership               0
# RegistrationDate         0
# Tenure                   0
# TotalSpend               0
# TotalTransactions        0
# AverageOrderValue        0
# PurchaseFrequency        0
# LastPurchaseDays         0
# PreferredCategory        0
# WebsiteVisits            0
# AppUsageMinutes          0
# LoginFrequency           0
# WishlistCount            0
# CartAbandonmentRate      0
# EmailOpenRate            0
# MarketingClicks          0
# SatisfactionScore        0
# Rating                   0
# SupportCalls             0
# Complaints               0
# Reviews                  0
# CustomerHealthScore      0
# ChurnRisk                0
# CustomerLifetimeValue    0
# NextPurchaseAmount       0
# NextPurchaseDays         0
# DiscountUsed             0
# CouponUsed               0
# ReferralCount            0
# PaymentMethod            0
# DeviceType               0
# ReturnRate               0
# LoyaltyPoints            0
# dtype: int64

# %%
df = df.drop(columns=[
    "CustomerID",
    "RegistrationDate",
    "CustomerLifetimeValue",
    "NextPurchaseDays",
    "NextPurchaseAmount"
])

# %%
label = LabelEncoder()

for col in df.select_dtypes(include="object").columns:

    if col != "NextPurchaseAmount":

        df[col] = label.fit_transform(df[col])

# %%
y = df["NextPurchaseAmount"]

print(X.shape)
print(y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y = df["NextPurchaseAmount"]
#       3 print(X.shape)
#       4 print(y.shape)
#
# NameError: name 'df' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(

    X,
    y,

    test_size=0.20,

    random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(
#       2
#       3     X,
#       4     y,
#       5
#       6     test_size=0.20,
#       7
#       8     random_state=42
#       9 )
#
# NameError: name 'train_test_split' is not defined

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 scaler = StandardScaler()
#       3 X_train_scaled = scaler.fit_transform(X_train)
#       5 X_test_scaled = scaler.transform(X_test)
#
# NameError: name 'StandardScaler' is not defined

# %%
models = {

    "Linear Regression": LinearRegression(),

    "Random Forest": RandomForestRegressor(
        random_state=42
    ),

    "Gradient Boosting": GradientBoostingRegressor(
        random_state=42
    ),

    "Extra Trees": ExtraTreesRegressor(
        random_state=42
    ),

    "XGBoost": XGBRegressor(
        random_state=42
    ),

    "LightGBM": LGBMRegressor(
        random_state=42
    ),

    "CatBoost": CatBoostRegressor(
        verbose=0,
        random_state=42
    )

}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 models = {
#       2
# ----> 3     "Linear Regression": LinearRegression(),
#       4
#       5     "Random Forest": RandomForestRegressor(
#       6         random_state=42
#       7     ),
#       8
#       9     "Gradient Boosting": GradientBoostingRegressor(
#      10         random_state=42
#      11     ),
#      12
#      13     "Extra Trees": ExtraTreesRegressor(
#      14         random_state=42
#      15     ),
#      16
#      17     "XGBoost": XGBRegressor(
#      18         random_state=42
#      19     ),
#      20
#      21     "LightGBM": LGBMRegressor(
#      22         random_state=42
#      23     ),
#      24
#      25     "CatBoost": CatBoostRegressor(
#      26         verbose=0,
#      27         random_state=42
#      28     )
#      29
#      30 }
#
# NameError: name 'LinearRegression' is not defined

# %%
results = []

for name, model in models.items():

    print(f"Training {name}...")

    if name == "Linear Regression":

        model.fit(
            X_train_scaled,
            y_train
        )

        pred = model.predict(
            X_test_scaled
        )

    else:

        model.fit(
            X_train,
            y_train
        )

        pred = model.predict(
            X_test
        )

    mae = mean_absolute_error(
        y_test,
        pred
    )

    rmse = np.sqrt(
        mean_squared_error(
            y_test,
            pred
        )
    )

    r2 = r2_score(
        y_test,
        pred
    )

    results.append({

        "Model": name,

        "MAE": mae,

        "RMSE": rmse,

        "R2 Score": r2

    })

print("Training Complete ✅")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 results = []
# ----> 3 for name, model in models.items():
#       5     print(f"Training {name}...")
#       7     if name == "Linear Regression":
#
# NameError: name 'models' is not defined

# %%
results_df = pd.DataFrame(results)

results_df.sort_values(

    by="R2 Score",

    ascending=False

)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 results_df = pd.DataFrame(results)
#       3 results_df.sort_values(
#       4
#       5     by="R2 Score",
#    (...)      8
#       9 )
#
# NameError: name 'pd' is not defined

# %%
import joblib
import os

os.makedirs(
    "models",
    exist_ok=True
)


best_model = models["Linear Regression"]


joblib.dump(
    best_model,
    "models/next_purchase_amount_model.pkl"
)


joblib.dump(
    scaler,
    "models/next_purchase_amount_scaler.pkl"
)


joblib.dump(
    X.columns.tolist(),
    "models/next_purchase_amount_features.pkl"
)


print("Next Purchase Amount Model Saved ✅")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       2 import os
#       4 os.makedirs(
#       5     "models",
#       6     exist_ok=True
#       7 )
# ---> 10 best_model = models["Linear Regression"]
#      13 joblib.dump(
#      14     best_model,
#      15     "models/next_purchase_amount_model.pkl"
#      16 )
#      19 joblib.dump(
#      20     scaler,
#      21     "models/next_purchase_amount_scaler.pkl"
#      22 )
#
# NameError: name 'models' is not defined

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Income', 'Location', 'Membership', 'Tenure',
#        'TotalSpend', 'TotalTransactions', 'AverageOrderValue',
#        'PurchaseFrequency', 'LastPurchaseDays', 'PreferredCategory',
#        'WebsiteVisits', 'AppUsageMinutes', 'LoginFrequency', 'WishlistCount',
#        'CartAbandonmentRate', 'EmailOpenRate', 'MarketingClicks',
#        'SatisfactionScore', 'Rating', 'SupportCalls', 'Complaints', 'Reviews',
#        'CustomerHealthScore', 'ChurnRisk', 'NextPurchaseAmount',
#        'DiscountUsed', 'CouponUsed', 'ReferralCount', 'PaymentMethod',
#        'DeviceType', 'ReturnRate', 'LoyaltyPoints'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['Age', 'Gender', 'Income', 'Location', 'Membership', 'Tenure',
#        'TotalSpend', 'TotalTransactions', 'AverageOrderValue',
#        'PurchaseFrequency', 'LastPurchaseDays', 'PreferredCategory',
#        'WebsiteVisits', 'AppUsageMinutes', 'LoginFrequency', 'WishlistCount',
#        'CartAbandonmentRate', 'EmailOpenRate', 'MarketingClicks',
#        'SatisfactionScore', 'Rating', 'SupportCalls', 'Complaints', 'Reviews',
#        'CustomerHealthScore', 'ChurnRisk', 'NextPurchaseAmount',
#        'DiscountUsed', 'CouponUsed', 'ReferralCount', 'PaymentMethod',
#        'DeviceType', 'ReturnRate', 'LoyaltyPoints'],
#       dtype='object')
