# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("/Users/aashishmewada/Desktop/PRISM AI/data/customer_segmentation (1).csv")

# %%
df.head()
# Out:
#    CustomerID  Age     Income  TotalSpend  TotalTransactions  \
# 0  CUST_00001   30   36145.43    16201.39                127
# 1  CUST_00002   33  116336.48    16206.03                 66
# 2  CUST_00003   29   33083.98     1137.59                 38
# 3  CUST_00004   47   62876.60     8849.93                166
# 4  CUST_00005   41  112443.26   188927.81                610
#
#    PurchaseFrequency  AverageOrderValue  Tenure  MonthlySpend  \
# 0                4.1             126.13     2.8        482.18
# 1                1.2             238.53     4.2        321.55
# 2                1.0              29.22     3.3         28.73
# 3                3.5              53.31     4.2        175.59
# 4                7.7             301.34     6.2       2539.35
#
#    LastPurchaseDays  SatisfactionScore
# 0                41                6.9
# 1               133                2.5
# 2               112                5.9
# 3                65                8.6
# 4                17                9.0

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Age                    0
# Income               108
# TotalSpend             0
# TotalTransactions      0
# PurchaseFrequency      0
# AverageOrderValue    116
# Tenure                 0
# MonthlySpend         133
# LastPurchaseDays       0
# SatisfactionScore    134
# dtype: int64

# %%
df.shape
# Out:
# (5000, 11)

# %%
df.info
# Out:
# <bound method DataFrame.info of       CustomerID  Age     Income  TotalSpend  TotalTransactions  \
# 0     CUST_00001   30   36145.43    16201.39                127
# 1     CUST_00002   33  116336.48    16206.03                 66
# 2     CUST_00003   29   33083.98     1137.59                 38
# 3     CUST_00004   47   62876.60     8849.93                166
# 4     CUST_00005   41  112443.26   188927.81                610
# ...          ...  ...        ...         ...                ...
# 4995  CUST_04996   25   20247.90       38.94                  1
# 4996  CUST_04997   46  161405.66   205098.25                662
# 4997  CUST_04998   19   67393.56      895.61                  8
# 4998  CUST_04999   43   42269.66      692.10                 21
# 4999  CUST_05000   48   90890.03    37927.36                258
#
#       PurchaseFrequency  AverageOrderValue  Tenure  MonthlySpend  \
# 0                   4.1             126.13     2.8        482.18
# 1                   1.2             238.53     4.2        321.55
# 2                   1.0              29.22     3.3         28.73
# 3                   3.5              53.31     4.2        175.59
# 4                   7.7             301.34     6.2       2539.35
# ...                 ...                ...     ...           ...
# 4995                0.2              36.91     0.1         32.45
# 4996                9.3             304.83     6.5       2629.46
# 4997                3.6             117.42     0.2        373.17
# 4998                0.7              33.80     2.3         25.08
# 4999                2.9             151.32     6.6        478.88
#
#       LastPurchaseDays  SatisfactionScore
# 0                   41                6.9
# 1                  133                2.5
# 2                  112                5.9
# 3                   65                8.6
# 4                   17                9.0
# ...                ...                ...
# 4995                15                5.6
# 4996                 1                8.5
# 4997                36                6.2
# 4998                64                4.4
# 4999                56                6.5
#
# [5000 rows x 11 columns]>

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Income', 'TotalSpend', 'TotalTransactions',
#        'PurchaseFrequency', 'AverageOrderValue', 'Tenure', 'MonthlySpend',
#        'LastPurchaseDays', 'SatisfactionScore'],
#       dtype='str')

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df,x="SatisfactionScore")
plt.title("customer_segmentation")
plt.xlabel("SatisfactionScore")
plt.ylabel("count")
plt.show()

# %%
df.head()
# Out:
#    CustomerID  Age     Income  TotalSpend  TotalTransactions  \
# 0  CUST_00001   30   36145.43    16201.39                127
# 1  CUST_00002   33  116336.48    16206.03                 66
# 2  CUST_00003   29   33083.98     1137.59                 38
# 3  CUST_00004   47   62876.60     8849.93                166
# 4  CUST_00005   41  112443.26   188927.81                610
#
#    PurchaseFrequency  AverageOrderValue  Tenure  MonthlySpend  \
# 0                4.1             126.13     2.8        482.18
# 1                1.2             238.53     4.2        321.55
# 2                1.0              29.22     3.3         28.73
# 3                3.5              53.31     4.2        175.59
# 4                7.7             301.34     6.2       2539.35
#
#    LastPurchaseDays  SatisfactionScore
# 0                41                6.9
# 1               133                2.5
# 2               112                5.9
# 3                65                8.6
# 4                17                9.0

# %%
num_columns=[
    'Income',
    'AverageOrderValue',
    'MonthlySpend',
    'SatisfactionScore',
    'SatisfactionLevel'
    ]

# %%
for col in num_columns:
    df[col] = df[col].fillna(df[col].median())

print("Numerical Missing Values Handled ✅")
# Out:
# Numerical Missing Values Handled ✅

# %%
df.head()
# Out:
#    CustomerID  Age     Income  TotalSpend  TotalTransactions  \
# 0  CUST_00001   30   36145.43    16201.39                127
# 1  CUST_00002   33  116336.48    16206.03                 66
# 2  CUST_00003   29   33083.98     1137.59                 38
# 3  CUST_00004   47   62876.60     8849.93                166
# 4  CUST_00005   41  112443.26   188927.81                610
#
#    PurchaseFrequency  AverageOrderValue  Tenure  MonthlySpend  \
# 0                4.1             126.13     2.8        482.18
# 1                1.2             238.53     4.2        321.55
# 2                1.0              29.22     3.3         28.73
# 3                3.5              53.31     4.2        175.59
# 4                7.7             301.34     6.2       2539.35
#
#    LastPurchaseDays  SatisfactionScore
# 0                41                6.9
# 1               133                2.5
# 2               112                5.9
# 3                65                8.6
# 4                17                9.0

# %%
df.isnull().sum()
# Out:
# CustomerID             0
# Age                    0
# Income               108
# TotalSpend             0
# TotalTransactions      0
# PurchaseFrequency      0
# AverageOrderValue    116
# Tenure                 0
# MonthlySpend         133
# LastPurchaseDays       0
# SatisfactionScore    134
# dtype: int64

# %%
df.to_csv(
    "cleaned_customer_segmentation",
    index=False
)

print("Clean Dataset Saved ✅")
# Out:
# Clean Dataset Saved ✅

# %%
df.drop("CustomerID", axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age     Income  TotalSpend  TotalTransactions  PurchaseFrequency  \
# 0   30   36145.43    16201.39                127                4.1
# 1   33  116336.48    16206.03                 66                1.2
# 2   29   33083.98     1137.59                 38                1.0
# 3   47   62876.60     8849.93                166                3.5
# 4   41  112443.26   188927.81                610                7.7
#
#    AverageOrderValue  Tenure  MonthlySpend  LastPurchaseDays  \
# 0             126.13     2.8        482.18                41
# 1             238.53     4.2        321.55               133
# 2              29.22     3.3         28.73               112
# 3              53.31     4.2        175.59                65
# 4             301.34     6.2       2539.35                17
#
#    SatisfactionScore
# 0                6.9
# 1                2.5
# 2                5.9
# 3                8.6
# 4                9.0

# %%
X = df[
[
"Age",
"Income",
"TotalSpend",
"TotalTransactions",
"PurchaseFrequency",
"AverageOrderValue",
"Tenure",
"MonthlySpend",
"SatisfactionScore"
]
]

# %%
X.head()
# Out:
#    Age     Income  TotalSpend  TotalTransactions  PurchaseFrequency  \
# 0   30   36145.43    16201.39                127                4.1
# 1   33  116336.48    16206.03                 66                1.2
# 2   29   33083.98     1137.59                 38                1.0
# 3   47   62876.60     8849.93                166                3.5
# 4   41  112443.26   188927.81                610                7.7
#
#    AverageOrderValue  Tenure  MonthlySpend  SatisfactionScore
# 0             126.13     2.8        482.18                6.9
# 1             238.53     4.2        321.55                2.5
# 2              29.22     3.3         28.73                5.9
# 3              53.31     4.2        175.59                8.6
# 4             301.34     6.2       2539.35                9.0

# %%
X.shape
# Out:
# (5000, 9)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (5000, 9)

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1,11):
    
    kmeans = KMeans(
        n_clusters=i,
        random_state=42
    )
    
    kmeans.fit(X_scaled)
    
    wcss.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 12
#       8         n_clusters=i,
#       9         random_state=42
#      10     )
#      11
# ---> 12     kmeans.fit(X_scaled)
#      13
#      14     wcss.append(kmeans.inertia_)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/cluster/_kmeans.py:1463, in KMeans.fit(self, X, y, sample_weight)
#    1435 @_fit_context(prefer_skip_nested_validation=True)
#    1436 def fit(self, X, y=None, sample_weight=None):
#    1437     """Compute k-means clustering.
#    1438
#    1439     Parameters
#    (...)   1461         Fitted estimator.
#    1462     """
# -> 1463     X = validate_data(
#    1464         self,
#    1465         X,
#    1466         accept_sparse="csr",
#    1467         dtype=[np.float64, np.float32],
#    1468         order="C",
#    1469         copy=self.copy_x,
#    1470         accept_large_sparse=False,
#    1471     )
#    1473     self._check_params_vs_input(X)
#    1475     random_state = check_random_state(self.random_state)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:1087, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1081     raise ValueError(
#    1082         f"Found array with dim {array.ndim},"
#    1083         f" while dim <= 2 is required{context}."
#    1084     )
#    1086 if ensure_all_finite:
# -> 1087     _assert_all_finite(
#    1088         array,
#    1089         input_name=input_name,
#    1090         estimator_name=estimator_name,
#    1091         allow_nan=ensure_all_finite == "allow-nan",
#    1092     )
#    1094 if copy:
#    1095     if _is_numpy_namespace(xp):
#    1096         # only make a copy if `array` and `array_orig` may share memory`
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:137, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     134 if first_pass_isfinite:
#     135     return
# --> 137 _assert_all_finite_element_wise(
#     138     X,
#     139     xp=xp,
#     140     allow_nan=allow_nan,
#     141     msg_dtype=msg_dtype,
#     142     estimator_name=estimator_name,
#     143     input_name=input_name,
#     144 )
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:186, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     169 if estimator_name and input_name == "X" and has_nan_error:
#     170     # Improve the error message on how to handle missing values in
#     171     # scikit-learn.
#     172     msg_err += (
#     173         f"\n{estimator_name} does not accept missing values"
#     174         " encoded as NaN natively. For supervised learning, you might want"
#    (...)    184         "#estimators-that-handle-nan-values"
#     185     )
# --> 186 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# KMeans does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
plt.figure(figsize=(8,5))

plt.plot(
    range(1,11),
    wcss,
    marker="o"
)

plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.title("Elbow Method")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 plt.figure(figsize=(8,5))
#       2
# ----> 3 plt.plot(
#       4     range(1,11),
#       5     wcss,
#       6     marker="o"
#
# File ~/Library/Python/3.14/lib/python/site-packages/matplotlib/pyplot.py:4043, in plot(scalex, scaley, data, *args, **kwargs)
#    4035 @_copy_docstring_and_deprecators(Axes.plot)
#    4036 def plot(
#    4037     *args: float | ArrayLike | str,
#    (...)   4041     **kwargs,
#    4042 ) -> list[Line2D]:
# -> 4043     return gca().plot(
#    4044         *args,
#    4045         scalex=scalex,
#    4046         scaley=scaley,
#    4047         **({"data": data} if data is not None else {}),
#    4048         **kwargs,
#    4049     )
#
# File ~/Library/Python/3.14/lib/python/site-packages/matplotlib/axes/_axes.py:1792, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1549 """
#    1550 Plot y versus x as lines and/or markers.
#    1551
#    (...)   1789 (``'green'``) or hex strings (``'#008000'``).
#    1790 """
#    1791 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1792 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1793 for line in lines:
#    1794     self.add_line(line)
#
# File ~/Library/Python/3.14/lib/python/site-packages/matplotlib/axes/_base.py:331, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     329     this += args[0],
#     330     args = args[1:]
# --> 331 yield from self._plot_args(
#     332     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     333     return_kwargs=return_kwargs
#     334 )
#
# File ~/Library/Python/3.14/lib/python/site-packages/matplotlib/axes/_base.py:509, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     506     axes.yaxis.update_units(y)
#     508 if x.shape[0] != y.shape[0]:
# --> 509     raise ValueError(f"x and y must have same first dimension, but "
#     510                      f"have shapes {x.shape} and {y.shape}")
#     511 if x.ndim > 2 or y.ndim > 2:
#     512     raise ValueError(f"x and y can be no greater than 2D, but have "
#     513                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (0,)

# %%
kmeans = KMeans(
    n_clusters=4,
    random_state=42
)

clusters = kmeans.fit_predict(X_scaled)

# %%
len(clusters)
# Out:
# 5000

# %%
df["Customer_Segment"] = clusters

# %%
df.head()
# Out:
#    Age     Income  TotalSpend  TotalTransactions  PurchaseFrequency  \
# 0   30   36145.43    16201.39                127                4.1
# 1   33  116336.48    16206.03                 66                1.2
# 2   29   33083.98     1137.59                 38                1.0
# 3   47   62876.60     8849.93                166                3.5
# 4   41  112443.26   188927.81                610                7.7
#
#    AverageOrderValue  Tenure  MonthlySpend  LastPurchaseDays  \
# 0             126.13     2.8        482.18                41
# 1             238.53     4.2        321.55               133
# 2              29.22     3.3         28.73               112
# 3              53.31     4.2        175.59                65
# 4             301.34     6.2       2539.35                17
#
#    SatisfactionScore AgeGroup  SatisfactionLevel  Customer_Segment
# 0                6.9      <30                  2                 1
# 1                2.5    30-39                  1                 0
# 2                5.9      <30                  2                 3
# 3                8.6    40-49                  0                 1
# 4                9.0    40-49                  0                 2

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for col in ["AgeGroup"]:
    df[col] = encoder.fit_transform(df[col])

print("Categorical Converted Successfully ✅")
# Out:
# Categorical Converted Successfully ✅

# %%
df.groupby("Customer_Segment").mean()
# Out:
#                         Age         Income     TotalSpend  TotalTransactions  \
# Customer_Segment
# 0                 47.227459  112573.403730    8852.201578          41.415984
# 1                 39.436754   75515.893379   17144.768067         145.554177
# 2                 44.606730  138927.290289  153660.434469         518.174553
# 3                 29.010914   40601.409874    1532.941637          26.550477
#
#                   PurchaseFrequency  AverageOrderValue    Tenure  \
# Customer_Segment
# 0                          0.583402         206.772592  5.974180
# 1                          3.275418         115.853527  3.742243
# 2                          7.596530         280.541588  5.707992
# 3                          1.163915          49.199969  1.988472
#
#                   MonthlySpend  LastPurchaseDays  SatisfactionScore  AgeGroup  \
# Customer_Segment
# 0                   123.777070        153.977459           3.334221  1.268443
# 1                   382.077446         34.809069           7.312888  1.231981
# 2                  2107.696866         11.313354           8.728181  1.203996
# 3                    76.017231         59.291269           5.944611  1.905184
#
#                   SatisfactionLevel
# Customer_Segment
# 0                          1.266393
# 1                          0.854415
# 2                          0.138801
# 3                          1.578445

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=clusters
)

plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.title("Customer Segmentation")

plt.show()
